# %% [markdown]
# # Using the OTX-Python-SDK

# %% [markdown]
# ## API Key Configuration

# %%
from OTXv2 import OTXv2, IndicatorTypes

# %%
from pandas.io.json import json_normalize

# %%
from datetime import datetime, timedelta

# %%
#otx = OTXv2("56eeceea60fe1afb077026f0d228342a74707e64852ae7dd3cbee8439ff4d59c")
otx = OTXv2("a0709959938ef8b855136a06f118a716df327ae1109c4a6c35685c42e38be4ca")

# %% [markdown]
# Replace YOUR_KEY with your OTX API key. You can find it on your settings page https://otx.alienvault.com/settings.

# %% [markdown]
# ## Subscriptions

# %% [markdown]
# The getall() method accesses your subscriptions.  It downloads all the OTX pulses and their assocciated indicators of compromise (IOCs) from your account. This includes:
# - All pulses you subscribe to directly
# - All pulses by users you subscribe to
# - OTX pulses you created (including private pulses)
# If this is the first time you are using your account, the download includes all pulses created by AlienVault. All users are subscribed to the AlienVault user by default.

# %%
pulses = otx.getall()

# %%
len(pulses)
# Out:
# 5

# %%
json_normalize(pulses)[0:5]
# Out:
# /var/folders/fn/f809r2_97k9cv7vfz0vgt_w00000gn/T/ipykernel_1775/633517224.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   json_normalize(pulses)[0:5]
#                          id  \
# 0  60ece5998a5b54a5ffe75cb4
# 1  5a64f74f0e543738c12bc973
# 2  6341d1aa0a02a3f6251ab540
# 3  64a7c62dda0c66ad822272ec
# 4  64a53b9c7fc8616c4ff6024f
#
#                                                 name  \
# 0                      SSH Brute-Force Honeypot Live
# 1  Webscanners with Bad Requests - HTTP Status 40...
# 2                    Sinking Yachts Phishing Domains
# 3                                  IPy Notebook Test
# 4                                  IPy Notebook Test
#
#                                          description author_name  \
# 0  every host is banned for 3 hours and receives ...    pr0viehh
# 1  Webscanners who&amp;amp;amp;#39;s requests res...      david3
# 2  Sinking Yachts is a Discord based anti-phishin...    __akac__
# 3                                                       pranavkr
# 4                                                       pranavkr
#
#                      modified                     created  revision    tlp  \
# 0  2024-03-31T20:31:20.973000  2021-07-13T01:00:09.665000         5  white
# 1  2024-03-31T20:20:16.926000  2018-01-21T20:25:51.668000         4  white
# 2  2024-03-31T19:40:30.790000  2022-10-08T19:38:18.341000     14410  white
# 3  2023-08-06T08:03:47.345000  2023-07-07T08:00:45.157000         1  green
# 4  2023-08-04T09:00:46.665000  2023-07-05T09:45:00.687000         1  green
#
#    public adversary                                         indicators  \
# 0       1            [{'id': 3659063371, 'indicator': '50.229.197.6...
# 1       1            [{'id': 3631657412, 'indicator': '5.161.117.81...
# 2       1            [{'id': 3655847998, 'indicator': 'stearncomrnu...
# 3       0                                                           []
# 4       0                                                           []
#
#                                                 tags targeted_countries  \
# 0           [Bruteforce, Brute-Force, SSH, Honeypot]                 []
# 1  [webscanner, bruteforce, badrequest, probing, ...                 []
# 2                 [discord, roblox, steam, phishing]                 []
# 3                                                 []                 []
# 4                                                 []                 []
#
#   malware_families attack_ids references industries extract_source  \
# 0               []         []         []         []             []
# 1               []         []         []         []             []
# 2               []         []         []   [gaming]             []
# 3               []         []         []         []             []
# 4               []         []         []         []             []
#
#    more_indicators
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %% [markdown]
# - author_name: The username of the OTX User that created the pulse
# - created: Date when the pulse was created in the system
# - description: Describes the pulse in terms of the type of threat it poses, and any other facts that may link it to other threat indicators.
# - id: Unique identifier of the pulse
# - indicators: Collection of Indicators Of Compromise
# - modified: Date when the pulse was last modified
# - name: Name of the pulse
# - references: List of references to papers, websites or blogs related to the threat described in the pulse
# - revision: Revision number that increments each time pulse contents change
# - tags: List of tags that provide information about pulse content, for example, Phshing, malware, C&C, and apt.

# %% [markdown]
# Let's explore the indicators object:

# %%
json_normalize(pulses[1]["indicators"])
# Out:
# /var/folders/fn/f809r2_97k9cv7vfz0vgt_w00000gn/T/ipykernel_1775/647023602.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   json_normalize(pulses[1]["indicators"])
#                id       indicator  type              created content  \
# 0      3631657412    5.161.117.81  IPv4  2023-02-11T00:05:15
# 1      3366197086   167.94.138.46  IPv4  2023-02-11T00:10:08
# 2      3631724497  176.97.210.177  IPv4  2023-02-11T00:10:16
# 3      3631724497  176.97.210.177  IPv4  2023-02-11T00:15:09
# 4      3631755626     3.80.221.68  IPv4  2023-02-11T00:15:17
# ...           ...             ...   ...                  ...     ...
# 29999  2279830927  192.241.230.46  IPv4  2024-03-31T19:50:07
# 30000  3548007530   172.104.11.51  IPv4  2024-03-31T20:00:15
# 30001  3854241386  166.88.141.168  IPv4  2024-03-31T20:00:17
# 30002  3422948472   205.210.31.17  IPv4  2024-03-31T20:10:06
# 30003  3603117133  107.170.248.15  IPv4  2024-03-31T20:20:17
#
#                  title description           expiration  is_active  \
# 0      400 BAD REQUEST              2023-05-12T00:00:00          1
# 1      400 BAD REQUEST              2023-05-12T00:00:00          1
# 2      400 BAD REQUEST              2023-05-12T00:00:00          1
# 3      400 BAD REQUEST              2023-05-12T00:00:00          1
# 4      400 BAD REQUEST              2023-05-12T00:00:00          1
# ...                ...         ...                  ...        ...
# 29999  400 BAD REQUEST              2024-06-29T00:00:00          1
# 30000  400 BAD REQUEST              2024-06-29T00:00:00          1
# 30001  400 BAD REQUEST              2024-06-29T00:00:00          1
# 30002  400 BAD REQUEST              2024-06-29T00:00:00          1
# 30003  400 BAD REQUEST              2024-06-29T00:00:00          1
#
#                 role
# 0      scanning_host
# 1      scanning_host
# 2      scanning_host
# 3      scanning_host
# 4      scanning_host
# ...              ...
# 29999  scanning_host
# 30000  scanning_host
# 30001  scanning_host
# 30002  scanning_host
# 30003  scanning_host
#
# [30004 rows x 10 columns]

# %% [markdown]
# - _id: Unique identifier of the IOC
# - created: Date IOC was added to the pulse
# - description: Describe the Indicator Of Compromise
# - indicator: The IOC
# - indicator_type: Type of indicator
#
# The following Indicator Types are supported (also defined in IndicatorTypes.py):

# %%
indicator_types = [
			{
			    "name": "IPv4", 
			    "description": "An IPv4 address indicating the online location of a server or other computer."
			}, 
			{
			    "name": "IPv6", 
			    "description": "An IPv6 address indicating the online location of a server or other computer."
			}, 
			{
			    "name": "domain", 
			    "description": "A domain name for a website or server. Domains encompass a series of hostnames."
			}, 
			{
			    "name": "hostname", 
			    "description": "The hostname for a server located within a domain."
			}, 
			{
			     
			    "name": "email", 
			    "description": "An email associated with suspicious activity."
			}, 
			{
			    "name": "URL", 
			    "description": " Uniform Resource Location (URL) summarizing the online location of a file or resource."
			}, 
			{
			     
			    "name": "URI", 
			    "description": "Uniform Resource Indicator (URI) describing the explicit path to a file hosted online."
			}, 
			{
			    "name": "FileHash-MD5", 
			    "description": "A MD5-format hash that summarizes the architecture and content of a file."
			}, 
			{
			    "name": "FileHash-SHA1", 
			    "description": "A SHA-format hash that summarizes the architecture and content of a file."
			}, 
			{
			    "name": "FileHash-SHA256", 
			    "description": "A SHA-256-format hash that summarizes the architecture and content of a file."
			}, 
			{
			     
			    "name": "FileHash-PEHASH", 
			    "description": "A PEPHASH-format hash that summarizes the architecture and content of a file."
			}, 
			{
			     
			    "name": "FileHash-IMPHASH", 
			    "description": "An IMPHASH-format hash that summarizes the architecture and content of a file."
			}, 
			{
			    "name": "CIDR", 
			    "description": "Classless Inter-Domain Routing (CIDR) address, which describes both a server's IP address and the network architecture (routing path) surrounding that server."
			}, 
			{
			     
			    "name": "FilePath", 
			    "description": "A unique location in a file system."
			}, 
			{
			     
			    "name": "Mutex", 
			    "description": "The name of a mutex resource describing the execution architecture of a file."
			}, 
			{
			    "name": "CVE", 
			    "description": "Common Vulnerability and Exposure (CVE) entry describing a software vulnerability that can be exploited to engage in malicious activity."
			}]

# %%
json_normalize(indicator_types)
# Out:
# /var/folders/fn/f809r2_97k9cv7vfz0vgt_w00000gn/T/ipykernel_1775/3949440694.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   json_normalize(indicator_types)
#                 name                                        description
# 0               IPv4  An IPv4 address indicating the online location...
# 1               IPv6  An IPv6 address indicating the online location...
# 2             domain  A domain name for a website or server. Domains...
# 3           hostname  The hostname for a server located within a dom...
# 4              email      An email associated with suspicious activity.
# 5                URL   Uniform Resource Location (URL) summarizing t...
# 6                URI  Uniform Resource Indicator (URI) describing th...
# 7       FileHash-MD5  A MD5-format hash that summarizes the architec...
# 8      FileHash-SHA1  A SHA-format hash that summarizes the architec...
# 9    FileHash-SHA256  A SHA-256-format hash that summarizes the arch...
# 10   FileHash-PEHASH  A PEPHASH-format hash that summarizes the arch...
# 11  FileHash-IMPHASH  An IMPHASH-format hash that summarizes the arc...
# 12              CIDR  Classless Inter-Domain Routing (CIDR) address,...
# 13          FilePath                A unique location in a file system.
# 14             Mutex  The name of a mutex resource describing the ex...
# 15               CVE  Common Vulnerability and Exposure (CVE) entry ...

# %%
mtime = (datetime.now() - timedelta(days=1)).isoformat()

# %%
mtime
# Out:
# '2024-03-31T02:03:15.307354'

# %% [markdown]
# ## Events

# %% [markdown]
# Besides receiving the pulse information, there is another function that can retrieve different events that are ocurring in the OTX system and affect your account.

# %%
events = otx.getevents_since(mtime)

# %%
json_normalize(events)
# Out:
# /var/folders/fn/f809r2_97k9cv7vfz0vgt_w00000gn/T/ipykernel_1775/1230498797.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   json_normalize(events)
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# - id: object id of this event.  Unique reference identifier
# - action : "[subscribe | unsubscribe | delete]", Currently supports subscribe / unsubscribe events for users and pulses and delete events for pulses
# - object_type : "[pulse | user]", // Currently supports events for pulse and user objects
# - object_id : "[pulse id | author id]", // Unique id can be used to lookup pulses and users (e.g. to remove them from  system, they would remove all pulses by author_id or an individual pulse by pulse "id".
# "created" : <timestamp of event>

# %% [markdown]
# When developing an application, you must decide how you want to handle different types of events. For instance, if one OTX user unsubscribes from another user, do you want to delete the IOCs the second user contributed from your application? How do you plan to reconcile the data on the server versus the data in your application?
# The same question comes up when users delete a pulse.

# %% [markdown]
# ## Using Search and get Pulse by ID

# %% [markdown]
# The OTX API allows you to search for pulses and users by keyword.  This allows you to obtain pulses that you're not (yet) subscribed to.

# %%
pulses = otx.search_pulses("Russian")

# %%
json_normalize(pulses["results"])
# Out:
# /var/folders/fn/f809r2_97k9cv7vfz0vgt_w00000gn/T/ipykernel_1775/1567407658.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   json_normalize(pulses["results"])
#                           id  \
# 0   5528132f13432a2102724d34
# 1   55346adeb45ff536ca3ffd2c
# 2   553583b5b45ff501cdc579aa
# 3   5541029cb45ff5029b148b7f
# 4   558d85f0b45ff55ccb25e6f4
# 5   55a7cbb7b45ff51f5c94e6a2
# 6   55dfc30067db8c7bb8cb9865
# 7   55fae83567db8c6fb3518bcd
# 8   55faf3014637f26df8745a74
# 9   565301b84637f2388ab004ca
# 10  5671b0604637f25637cffe86
# 11  56747dfa4637f25637d08132
# 12  567a9bf967db8c417529da86
# 13  567af83c4637f21e1c24d4ba
# 14  568b2cef4637f2624bcdbf2c
# 15  569ac29767db8c057c6fdcc8
# 16  569d38d74637f2624bcddaa8
# 17  56cb95eb67db8c5860d245d2
# 18  56d0a04667db8c48093080b7
# 19  56d0a89467db8c4809308123
# 20  5710fba53d1aa4023873a2d1
# 21  571b325a3c4c3e015d93c33f
# 22  57238ca37b3d46015f793bcf
# 23  572887524d42e3015db731d9
# 24  5731bc95452c27015dad07e0
#
#                                                  name  \
# 0            Potential TV5 Monde intrusion indicators
# 1                               Operation RussianDoll
# 2                                   Operation Buhtrap
# 3                                Operation Armageddon
# 4                 Digital Attack on German Parliament
# 5   Microsoft Office Zero-Day CVE-2015-2424 Levera...
# 6      New Spear Phishing Campaign Pretends to be EFF
# 7        THE DUKES: 7 years of Russian cyberespionage
# 8         Targeted Attack Distributes PlugX in Russia
# 9            Phishing site running suspicious scripts
# 10  Scanning Host - DNS query amplification attemp...
# 11                                       ZBot Malware
# 12  BBSRAT Attacks Targeting Russian Orgs Linked t...
# 13     BBSRAT Attacks Targeting Russian Organizations
# 14            Spam: New Year, New Russian Girlfriend!
# 15                                BlackEnergy Malware
# 16  Malicious Code Analysis on Ukraine's Power Gri...
# 17  Russian bank employees got fake job offers in ...
# 18             20160203-BlackEnergy by maldoc,Malware
# 19     20160204: CVE-2014-4114 Sandworm is not a WORM
# 20               Possible Credential Stealing Malware
# 21                  The Ghost Dragon - Cylance Report
# 22                                  BrLock ransomware
# 23   Remote Code Execution Attempt / auto append file
# 24                                  Enigma ransomware
#
#                                           description  \
# 0   TV5Monde was taken off air in April 2015. A gr...
# 1   FireEye Labs recently detected a limited APT c...
# 2   Operation Buhtrap - The trap for Russian accou...
# 3   “Operation Armageddon,” active since at least ...
# 4   Servers of The Left in German Bundestag have b...
# 5   Yesterday, Microsoft patched CVE-2015-2424, a ...
# 6   Google's security team recently identified a n...
# 7   The Dukes are a well-resourced, highly dedicat...
# 8   Proofpoint researchers recently observed a cam...
# 9   Found phishing sites using the same format of ...
# 10  Intense DNS query amplification attempt from R...
# 11  The Trojans designed to steal money from bank ...
# 12  In late 2014, ESET presented an attack campaig...
# 13  In late 2014, ESET presented an attack campaig...
# 14       Fake Russian girlfriend-themed spam campaign
# 15  These attacks are active and ongoing as of ear...
# 16  At the end of December 2015, the network syste...
# 17  Employees at six Russian banks were sent spoof...
# 18  Black Energy is a malware that was believed to...
# 19  Cyphort labs team found that the exploit paylo...
# 20  We found a machine on our network making suspi...
# 21  Cylance SPEAR™ has identified an APT group whi...
# 22  BrLock was found on April 18, 2016, but the ex...
# 23  Attempting to append the pot. analysis of the ...
# 24  A new ransomware called Enigma was discovered ...
#
#                   author_name                    modified  \
# 0                  AlienVault  2019-01-25T15:20:10.359000
# 1                  AlienVault  2017-08-24T10:45:07.905000
# 2                      tomdaq  2015-04-20T22:54:45.662000
# 3                  AlienVault  2017-03-12T01:33:45.089000
# 4                  AlienVault  2017-07-24T12:00:41.708000
# 5                  AlienVault  2019-10-24T16:03:41.314000
# 6                  AlienVault  2015-08-28T02:10:08.167000
# 7                  AlienVault  2017-03-06T17:17:18.888000
# 8                  AlienVault  2015-09-17T17:06:09.914000
# 9                   muscothym  2015-11-23T12:16:53.725000
# 10                renan.lopes  2015-12-16T18:41:36.827000
# 11                 AlienVault  2019-05-16T15:31:22.466000
# 12  brandongwalters@eaton.com  2015-12-23T13:04:57.822000
# 13                 AlienVault  2017-07-22T10:17:47.604000
# 14                    rpsanch  2016-01-05T02:39:43.063000
# 15          liveck@pta.center  2016-01-16T22:23:29.872000
# 16                 AlienVault  2016-01-18T19:11:19.403000
# 17                 AlienVault  2016-02-22T23:12:43.852000
# 18                    rpsanch  2016-02-26T18:58:14.597000
# 19                    rpsanch  2016-02-26T19:33:40.006000
# 20                  sredwards  2016-04-19T15:00:42.456000
# 21             CyberAnarchist  2016-04-23T08:29:14.035000
# 22                  bartblaze  2016-04-29T16:32:35.621000
# 23                    Umbra00  2016-05-03T11:11:14.151000
# 24                  bartblaze  2016-05-11T12:17:46.494000
#
#                        created tags references  public        adversary  ...  \
# 0   2015-04-10T18:15:11.492000   []         []       1           Sofacy  ...
# 1   2015-04-20T02:56:30.505000   []         []       1           Sofacy  ...
# 2   2015-04-20T22:54:45.662000   []         []       1             None  ...
# 3   2015-04-29T16:11:08.251000   []         []       1  Gamaredon Group  ...
# 4   2015-06-26T17:03:44.800000   []         []       1           Sofacy  ...
# 5   2015-07-16T15:20:23.492000   []         []       1             None  ...
# 6   2015-08-28T02:10:08.167000   []         []       1             None  ...
# 7   2015-09-17T16:20:05.303000   []         []       1           APT 29  ...
# 8   2015-09-17T17:06:09.914000   []         []       1             None  ...
# 9   2015-11-23T12:08:24.397000   []         []       1             None  ...
# 10  2015-12-16T18:41:36.827000   []         []       1             None  ...
# 11  2015-12-18T21:43:22.913000   []         []       1             None  ...
# 12  2015-12-23T13:04:57.822000   []         []       1             None  ...
# 13  2015-12-23T19:38:36.636000   []         []       1    Roaming Tiger  ...
# 14  2016-01-05T02:39:43.063000   []         []       1             None  ...
# 15  2016-01-16T22:22:15.592000   []         []       1             None  ...
# 16  2016-01-18T19:11:19.403000   []         []       1             None  ...
# 17  2016-02-22T23:12:43.852000   []         []       1             None  ...
# 18  2016-02-26T18:58:14.597000   []         []       1             None  ...
# 19  2016-02-26T19:33:40.006000   []         []       1             None  ...
# 20  2016-04-15T14:33:09.525000   []         []       1             None  ...
# 21  2016-04-23T08:29:14.035000   []         []       1             None  ...
# 22  2016-04-29T16:32:35.621000   []         []       1             None  ...
# 23  2016-05-03T11:11:14.151000   []         []       1             None  ...
# 24  2016-05-10T10:48:53.586000   []         []       1             None  ...
#
#       TLP revision groups in_group is_subscribing            author.username  \
# 0   green       11     []    False           None                 AlienVault
# 1   green        3     []    False           None                 AlienVault
# 2   green        1     []    False           None                     tomdaq
# 3   green        7     []    False           None                 AlienVault
# 4   green        5     []    False           None                 AlienVault
# 5   green        1     []    False           None                 AlienVault
# 6   green        1     []    False           None                 AlienVault
# 7   green        2     []    False           None                 AlienVault
# 8   green        1     []    False           None                 AlienVault
# 9   green       10     []    False           None                  muscothym
# 10  green        1     []    False           None                renan.lopes
# 11  green        2     []    False           None                 AlienVault
# 12  green        1     []    False           None  brandongwalters@eaton.com
# 13  green        2     []    False           None                 AlienVault
# 14  green        1     []    False           None                    rpsanch
# 15  green        2     []    False           None          liveck@pta.center
# 16  green        1     []    False           None                 AlienVault
# 17  green        1     []    False           None                 AlienVault
# 18  green        1     []    False           None                    rpsanch
# 19  green        1     []    False           None                    rpsanch
# 20  green       19     []    False           None                  sredwards
# 21  white        1     []    False           None             CyberAnarchist
# 22  green        1     []    False           None                  bartblaze
# 23  green        1     []    False           None                    Umbra00
# 24  green        2     []    False           None                  bartblaze
#
#    author.id                                  author.avatar_url  \
# 0          2  /otxapi/users/avatar_image/media/avatars/user_...
# 1          2  /otxapi/users/avatar_image/media/avatars/user_...
# 2         49  https://otx.alienvault.com/assets/images/defau...
# 3          2  /otxapi/users/avatar_image/media/avatars/user_...
# 4          2  /otxapi/users/avatar_image/media/avatars/user_...
# 5          2  /otxapi/users/avatar_image/media/avatars/user_...
# 6          2  /otxapi/users/avatar_image/media/avatars/user_...
# 7          2  /otxapi/users/avatar_image/media/avatars/user_...
# 8          2  /otxapi/users/avatar_image/media/avatars/user_...
# 9       6895  /otxapi/users/avatar_image/media/avatars/musco...
# 10      5557  /otxapi/users/avatar_image/media/avatars/renan...
# 11         2  /otxapi/users/avatar_image/media/avatars/user_...
# 12      5792  /otxapi/users/avatar_image/media/avatars/brand...
# 13         2  /otxapi/users/avatar_image/media/avatars/user_...
# 14      7584  https://otx.alienvault.com/assets/images/defau...
# 15      7748  https://otx.alienvault.com/assets/images/defau...
# 16         2  /otxapi/users/avatar_image/media/avatars/user_...
# 17         2  /otxapi/users/avatar_image/media/avatars/user_...
# 18      7584  https://otx.alienvault.com/assets/images/defau...
# 19      7584  https://otx.alienvault.com/assets/images/defau...
# 20      3255  https://otx.alienvault.com/assets/images/defau...
# 21      2064  /otxapi/users/avatar_image/media/avatars/Cyber...
# 22      1009  /otxapi/users/avatar_image/media/avatars/bartb...
# 23     14010  /otxapi/users/avatar_image/media/avatars/Umbra...
# 24      1009  /otxapi/users/avatar_image/media/avatars/bartb...
#
#    author.is_subscribed author.is_following
# 0                 False               False
# 1                 False               False
# 2                 False               False
# 3                 False               False
# 4                 False               False
# 5                 False               False
# 6                 False               False
# 7                 False               False
# 8                 False               False
# 9                 False               False
# 10                False               False
# 11                False               False
# 12                False               False
# 13                False               False
# 14                False               False
# 15                False               False
# 16                False               False
# 17                False               False
# 18                False               False
# 19                False               False
# 20                False               False
# 21                False               False
# 22                False               False
# 23                False               False
# 24                False               False
#
# [25 rows x 24 columns]

# %% [markdown]
# Let's say we're interested in viewing the full details (including indicators) from one of our search results.  For example maybe we're interested in the Enigma Ransomware:

# %%
pulse_id = pulses["results"][1]["id"]

# %%
pulse_details = otx.get_pulse_details(pulse_id)

# %%
json_normalize(pulse_details)
# Out:
# /var/folders/fn/f809r2_97k9cv7vfz0vgt_w00000gn/T/ipykernel_1775/4271244268.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   json_normalize(pulse_details)
#                          id                   name  \
# 0  55346adeb45ff536ca3ffd2c  Operation RussianDoll
#
#                                          description author_name  \
# 0  FireEye Labs recently detected a limited APT c...  AlienVault
#
#                      modified                     created  \
# 0  2017-08-24T10:45:07.905000  2015-04-20T02:56:30.505000
#
#                                                 tags references  public  \
# 0  [flash, apt28, windows, apt, shellcode, zeroda...         []       1
#
#   adversary  ...                                         indicators revision  \
# 0    Sofacy  ...  [{'id': 4278, 'indicator': 'ssl-icloud.com', '...        3
#
#                                               groups in_group is_subscribing  \
# 0  [{'name': 'APT28/Sofacy/Fancy Bear Working Gro...     True           None
#
#   author.username  author.id  \
# 0      AlienVault          2
#
#                                    author.avatar_url  author.is_subscribed  \
# 0  /otxapi/users/avatar_image/media/avatars/user_...                 False
#
#   author.is_following
# 0               False
#
# [1 rows x 25 columns]

# %% [markdown]
# ## Indicator details

# %% [markdown]
# Let's investigate an indicator included in the Enigma Ransomware pulse.

# %%
indicator = pulse_details["indicators"][4]["indicator"]

# %%
indicator_details = otx.get_indicator_details_full(IndicatorTypes.IPv4, indicator)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 indicator_details = otx.get_indicator_details_full(IndicatorTypes.IPv4, indicator)
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/OTXv2.py:682, in OTXv2.get_indicator_details_full(self, indicator_type, indicator)
#     680 for section in indicator_type.sections:
#     681     indicator_url = self.create_indicator_detail_url(indicator_type, indicator, section)
# --> 682     indicator_dict[section] = self.get(indicator_url)
#     683 return indicator_dict
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/OTXv2.py:185, in OTXv2.get(self, url, **kwargs)
#     177 try:
#     178     response = self.session().get(
#     179         self.create_url(url, **kwargs),
#     180         headers=self.headers,
#    (...)
#     183         cert=self.cert,
#     184     )
# --> 185     return self.handle_response_errors(response).json()
#     186 except requests.exceptions.RetryError:
#     187     raise RetryError()
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/OTXv2.py:162, in OTXv2.handle_response_errors(cls, response)
#     160     raise InvalidAPIKey()
#     161 elif response.status_code == 400:
# --> 162     raise BadRequest(_response_json())
#     163 elif response.status_code == 404:
#     164     raise NotFound()
#
# BadRequest: {'detail': 'Invalid IP (updatecenter.name)'}

# %% [markdown]
# Indicator details are divided into sections for convenience:

# %%
indicator_details.keys()
# Out:
# ['malware', 'passive_dns', 'url_list', 'general', 'reputation', 'geo']

# %%
json_normalize(indicator_details["url_list"])
# Out:
#    actual_size  full_size has_next  limit  page_num paged  \
# 0           22         22     True     10         1  True
#
#                                             url_list
# 0  [{u'domain': u'', u'url': u'http://82.194.84.1...

# %%
json_normalize(indicator_details["passive_dns"].get('passive_dns'))
# Out:
#          address asset_type                first flag_title  \
# 0  82.194.84.120     domain  2013-08-29 14:59:51      Spain
# 1  82.194.84.120     domain  2013-10-09 18:09:10      Spain
# 2  82.194.84.120     domain  2013-08-31 15:02:04      Spain
#
#                    flag_url                   hostname  \
# 0  /static/img/flags/es.png               comitres.net
# 1  /static/img/flags/es.png                 apamac.net
# 2  /static/img/flags/es.png  estudio-danza-camargo.com
#
#                                 indicator_link                 last
# 0               /indicator/domain/comitres.net  2014-07-24 01:04:39
# 1                 /indicator/domain/apamac.net  2013-12-16 15:42:58
# 2  /indicator/domain/estudio-danza-camargo.com  2013-08-31 15:02:04

# %% [markdown]
# Indicator details are not available for all supported indicator types.  IndicatorTypes.supported_api_types contains a list of the indicator types you can use with get_indicator_details_by_section and get_indicator_details_full.

# %% [markdown]
# ## Create pulse

# %% [markdown]
# You can create new pulses using the create_pulse function.  A name string is required.  Public boolean is also required but will be set True if not provided:

# %%
indicators = [{"indicator": "82.194.84.121", "description":"", "type": "IPv4"}, {"indicator": "82.194.84.122", "description":"", "type": "IPv4"}]

# %%
new_pulse = otx.create_pulse(name="IPy Notebook Test", indicators=indicators, public=False)

# %%
json_normalize(new_pulse)
# Out:
#      TLP active  author_id                author_name cloned_from  \
# 0  green   True      14830  hilaryclintonsemailserver        None
#
#    comments_count                     created description downvotes  \
# 0               0  2016-05-20T16:25:59.670399                    []
#
#    downvotes_count     ...      subscribers subscribers_count tags tags_count  \
# 0                0     ...               []                 0   []          0
#
#    unsubscribed_users upvotes upvotes_count validators validators_count  \
# 0                  []      []             0         []                0
#
#   votes_count
# 0           0
#
# [1 rows x 38 columns]

# %%
import pandas as pd
import schedule
import time
import datetime

def get_pulse_indicator_info(pulse_id, api_key):
    otx = OTXv2(api_key)

 
    indicators = otx.get_pulse_indicators(pulse_id)

    
    indicator_types = []
    indicator_values = []
    descriptions = []

    
    for indicator in indicators:
        indicator_types.append(indicator["type"])
        indicator_values.append(indicator["indicator"])
        descriptions.append(indicator["description"])

    
    return indicator_types, indicator_values, descriptions

def save_to_csv():
    indicator_types, indicator_values, descriptions = get_pulse_indicator_info(pulse_id, api_key)
    
    #lists into a DataFrame
    data = {
        "Indicator Types": indicator_types,
        "Indicator Values": indicator_values,
        "Descriptions": descriptions
    }
    df = pd.DataFrame(data)

    df = df.drop_duplicates(subset=["Indicator Values"])
    
    #save to new file
    current_time = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
    filename = f'pulse_indicators_{current_time}.csv'
    
    df.to_csv(filename, index=False)
    
    print(f"Data saved to {filename}")


api_key = "56eeceea60fe1afb077026f0d228342a74707e64852ae7dd3cbee8439ff4d59c"
pulse_id = "6341d1aa0a02a3f6251ab540"

save_to_csv()

# To change time 
schedule.every(6).hours.do(save_to_csv)

while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# Data saved to pulse_indicators_2024-01-22_10-40-49.csv

# %% [markdown]
# The following fields can be passed into create_pulse:
# - name(string, required) pulse name
# - public(boolean, required) long form description of threat
# - description(string) long form description of threat
# - tlp(string, white/green/amber/red) Traffic Light Protocol level for threat sharing
# - tags(list of strings) short keywords to associate with your pulse
# - references(list of strings, preferably URLs) external references for this threat
# - indicators(list of objects) IOCs to include in pulse
